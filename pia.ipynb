# %% [markdown]
# # Paso 1.- CREAR CARPETAS PARA IMAGENES
# crearemos una carpeta para cada fruta con la que entrenaremos la red neuronal

# %%
#Crear las carpetas para subir las imagenes
# !mkdir apples
# !mkdir banana
# !mkdir cherry
# !mkdir chickoo
# !mkdir grapes
# !mkdir kiwi
# !mkdir mango
# !mkdir orange
# !mkdir strawberry

# %% [markdown]
# despues se cargan los archivos zip en cada carpeta que se creo arrastrando el archivo .zip a cada carpeta, segun sea la fruta

# %% [markdown]
# NOTA: Los archivos utilizados se encuentran en el siguiente enlace
# https://drive.google.com/drive/u/0/folders/1ce0xFLnFkb8oauzV7EmOlT0D0Yl-9pb4

# %% [markdown]
# # Paso 2.- EXTRAER IMAGENES DE ARCHIVO ZIP
# ya con los archivos .zip en cada carpeta procederemos a extraer los archivos de los zip

# %%
#Entrar en cada carpeta y descomprimir el archivo zip
# %cd apples
# !unzip apples.zip
# %cd ..

# %cd banana
# !unzip banana.zip
# %cd ..

# %cd cherry
# !unzip cherry.zip
# %cd ..

# %cd chickoo
# !unzip chickoo.zip
# %cd ..

# %cd grapes
# !unzip grapes.zip
# %cd ..

# %cd kiwi
# !unzip kiwi.zip
# %cd ..
# %cd mango
# !unzip mango.zip
# %cd ..

# %cd orange
# !unzip orange.zip
# %cd ..

# %cd strawberry
# !unzip strawberry.zip
# %cd ..
# Out:
# /content/apples
# Archive:  apples.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.jpg
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.png
#   inflating: Image_14.png
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpeg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.png
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.png
#   inflating: Image_29.jpg
#   inflating: Image_3.jpeg
#   inflating: Image_30.jpg
#   inflating: Image_31.png
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpeg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.jpg
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpg
#   inflating: Image_40.jpeg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/banana
# Archive:  banana.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.png
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpeg
#   inflating: Image_30.jpg
#   inflating: Image_31.jpeg
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.png
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.JPG
#   inflating: Image_40.png
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/cherry
# Archive:  cherry.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.jpeg
#   inflating: Image_11.jpeg
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.png
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpg
#   inflating: Image_30.jpg
#   inflating: Image_31.jpg
#   inflating: Image_32.jpeg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.jpg
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpeg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/chickoo
# Archive:  chickoo.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.jpg
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.png
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.jpg
#   inflating: Image_25.JPG
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.png
#   inflating: Image_29.jpg
#   inflating: Image_3.png
#   inflating: Image_30.jpg
#   inflating: Image_31.jpeg
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.jpg
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/grapes
# Archive:  grapes.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.jpg
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpeg
#   inflating: Image_30.jpeg
#   inflating: Image_31.jpg
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpeg
#   inflating: Image_37.jpg
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/kiwi
# Archive:  kiwi.zip
#   inflating: Image_1.png
#   inflating: Image_10.jpg
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpeg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.png
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpg
#   inflating: Image_30.jpg
#   inflating: Image_31.jpg
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.JPG
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/mango
# Archive:  mango.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.JPG
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.gif
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.png
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.JPG
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpeg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpg
#   inflating: Image_30.jpg
#   inflating: Image_31.jpg
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.jpeg
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/orange
# Archive:  orange.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.jpg
#   inflating: Image_11.JPG
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.jpg
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpg
#   inflating: Image_30.jpg
#   inflating: Image_31.jpg
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpeg
#   inflating: Image_35.jpg
#   inflating: Image_36.JPG
#   inflating: Image_37.jpg
#   inflating: Image_38.jpg
#   inflating: Image_39.JPG
#   inflating: Image_4.jpg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content
# /content/strawberry
# Archive:  strawberry.zip
#   inflating: Image_1.jpg
#   inflating: Image_10.jpg
#   inflating: Image_11.jpg
#   inflating: Image_12.jpg
#   inflating: Image_13.jpg
#   inflating: Image_14.jpg
#   inflating: Image_15.jpg
#   inflating: Image_16.jpg
#   inflating: Image_17.jpg
#   inflating: Image_18.jpg
#   inflating: Image_19.jpg
#   inflating: Image_2.jpg
#   inflating: Image_20.jpg
#   inflating: Image_21.jpg
#   inflating: Image_22.jpg
#   inflating: Image_23.jpg
#   inflating: Image_24.png
#   inflating: Image_25.jpg
#   inflating: Image_26.jpg
#   inflating: Image_27.jpg
#   inflating: Image_28.jpg
#   inflating: Image_29.jpg
#   inflating: Image_3.jpg
#   inflating: Image_30.jpg
#   inflating: Image_31.png
#   inflating: Image_32.jpg
#   inflating: Image_33.jpg
#   inflating: Image_34.jpeg
#   inflating: Image_35.jpg
#   inflating: Image_36.jpg
#   inflating: Image_37.jpg
#   inflating: Image_38.jpg
#   inflating: Image_39.jpg
#   inflating: Image_4.jpg
#   inflating: Image_40.jpg
#   inflating: Image_5.jpg
#   inflating: Image_6.jpg
#   inflating: Image_7.jpg
#   inflating: Image_8.jpg
#   inflating: Image_9.jpg
# /content

# %% [markdown]
# despues de que ya hayamos confirmado que los archivos se extrageron correctamente, procedemos a eliminar los archivos .zip ya que solo ocuparan espacio y ya no los vamos a necesitar

# %%
#Borrar los archivo ZIP
# !rm -rf /content/apples/apples.zip
# !rm -rf /content/banana/banana.zip
# !rm -rf /content/cherry/cherry.zip
# !rm -rf /content/chickoo/chickoo.zip
# !rm -rf /content/grapes/grapes.zip
# !rm -rf /content/kiwi/kiwi.zip
# !rm -rf /content/mango/mango.zip
# !rm -rf /content/orange/orange.zip
# !rm -rf /content/strawberry/strawberry.zip

# %% [markdown]
# verificamos que todas las carpetas tengan la misma cantidad de archivos

# %%
#Mostrar cuantas imagenes tengo de cada categoria
# !ls /content/apples | wc -l
# !ls /content/banana | wc -l
# !ls /content/cherry | wc -l
# !ls /content/chickoo | wc -l
# !ls /content/grapes | wc -l
# !ls /content/kiwi | wc -l
# !ls /content/mango | wc -l
# !ls /content/orange | wc -l
# !ls /content/strawberry | wc -l
# Out:
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40
# 40

# %% [markdown]
# con matplot verificamos el contenido de alguna carpeta para ver si los tamaños de las imagenes son parecidos

# %%
#Mostrar algunas imagenes con pyplot
import os
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

plt.figure(figsize=(15,15))

carpeta = '/content/apples'
imagenes = os.listdir(carpeta)

for i, nombreimg in enumerate(imagenes[:25]):
  plt.subplot(5,5,i+1)
  imagen = mpimg.imread(carpeta + '/' + nombreimg)
  plt.imshow(imagen)

# %% [markdown]
# # Paso 3.- CREAR SET DE DATOS
# procederemos a crear nuestro set de datos, comenzando por crear las carpetas donde almacenaremos las imagenes editadas

# %%
#Crear carpetas para hacer el set de datos
#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
# !mkdir dataset
# !mkdir dataset/apples
# !mkdir dataset/banana
# !mkdir dataset/cherry
# !mkdir dataset/chickoo
# !mkdir dataset/grapes
# !mkdir dataset/kiwi
# !mkdir dataset/mango
# !mkdir dataset/orange
# !mkdir dataset/strawberry

# %% [markdown]
# despues copiamos en nuestra carpeta de dataset las imagenes que habiamos subido al principio, esto lo haremos carpeta por carpeta para que no se vayan a mezclar imagenes

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, banana, cherry, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/apples'
carpeta_destino = '/content/dataset/apples'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, banana, cherry, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/banana'
carpeta_destino = '/content/dataset/banana'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/cherry'
carpeta_destino = '/content/dataset/cherry'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/chickoo'
carpeta_destino = '/content/dataset/chickoo'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/grapes'
carpeta_destino = '/content/dataset/grapes'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/kiwi'
carpeta_destino = '/content/dataset/kiwi'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/mango'
carpeta_destino = '/content/dataset/mango'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/orange'
carpeta_destino = '/content/dataset/orange'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %%
#Copiar imagenes que subimos a carpetas del dataset

#apples, bananas, cherrys, chickoo,
#grapes, kiwi, mango, orange, strawberry
import shutil
carpeta_fuente = '/content/strawberry'
carpeta_destino = '/content/dataset/strawberry'

imagenes = os.listdir(carpeta_fuente)

for i, nombreimg in enumerate(imagenes):
  if i < 40:
    #Copia de la carpeta fuente a la destino
    shutil.copy(carpeta_fuente + '/' + nombreimg, carpeta_destino + '/' + nombreimg)

# %% [markdown]
# # Paso 4.- AUMENTO DE DATOS
# utilizando el ImageDataGeneratod de Tensorflow generaremos un aumento de datos para que el entrenamiento tenga mas imagenes con cuales trabajar

# %%
#Aumento de datos con ImageDataGenerator
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np

#Crear el dataset generador
datagen = ImageDataGenerator(
    rescale=1. / 255,
    rotation_range = 30,
    width_shift_range = 0.25,
    height_shift_range = 0.25,
    shear_range = 15,
    zoom_range = [0.5, 1.5],
    validation_split=0.2 #20% para pruebas
)

#Generadores para sets de entrenamiento y pruebas
data_gen_entrenamiento = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='training')
data_gen_pruebas = datagen.flow_from_directory('/content/dataset', target_size=(224,224),
                                                     batch_size=32, shuffle=True, subset='validation')

#Imprimir 10 imagenes del generador de entrenamiento
for imagen, etiqueta in data_gen_entrenamiento:
  for i in range(10):
    plt.subplot(2,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.imshow(imagen[i])
  break
plt.show()
# Out:
# Found 288 images belonging to 9 classes.
# Found 71 images belonging to 9 classes.

# %%
import tensorflow as tf
import tensorflow_hub as hub

url = "https://tfhub.dev/google/tf2-preview/mobilenet_v2/feature_vector/4"
mobilenetv2 = hub.KerasLayer(url, input_shape=(224,224,3))

# %%
#Congelar el modelo descargado
mobilenetv2.trainable = False

# %%
modelo = tf.keras.Sequential([
    mobilenetv2,
    tf.keras.layers.Dense(9, activation='softmax')
])

# %%
modelo.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  keras_layer (KerasLayer)    (None, 1280)              2257984
#
#  dense_1 (Dense)             (None, 9)                 11529
#
# =================================================================
# Total params: 2269513 (8.66 MB)
# Trainable params: 11529 (45.04 KB)
# Non-trainable params: 2257984 (8.61 MB)
# _________________________________________________________________

# %%
#Compilar como siempre
modelo.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# %%
#Entrenar el modelo
EPOCAS = 50

historial = modelo.fit(
    data_gen_entrenamiento, epochs=EPOCAS, batch_size=32,
    validation_data=data_gen_pruebas
)
# Out:
# Epoch 1/50
# 9/9 [==============================] - 21s 2s/step - loss: 2.1366 - accuracy: 0.2569 - val_loss: 1.5394 - val_accuracy: 0.4930
# Epoch 2/50
# 9/9 [==============================] - 16s 2s/step - loss: 1.2574 - accuracy: 0.6424 - val_loss: 0.9640 - val_accuracy: 0.7746
# Epoch 3/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.8588 - accuracy: 0.7986 - val_loss: 0.6738 - val_accuracy: 0.8310
# Epoch 4/50
# 9/9 [==============================] - 19s 2s/step - loss: 0.6047 - accuracy: 0.8542 - val_loss: 0.5159 - val_accuracy: 0.9014
# Epoch 5/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.5132 - accuracy: 0.8750 - val_loss: 0.4296 - val_accuracy: 0.9155
# Epoch 6/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.4200 - accuracy: 0.8958 - val_loss: 0.4245 - val_accuracy: 0.9014
# Epoch 7/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.3549 - accuracy: 0.9167 - val_loss: 0.3384 - val_accuracy: 0.9577
# Epoch 8/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.3167 - accuracy: 0.9236 - val_loss: 0.3036 - val_accuracy: 0.9155
# Epoch 9/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.2944 - accuracy: 0.9201 - val_loss: 0.2189 - val_accuracy: 0.9718
# Epoch 10/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.2671 - accuracy: 0.9306 - val_loss: 0.2567 - val_accuracy: 0.9577
# Epoch 11/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.2504 - accuracy: 0.9479 - val_loss: 0.2379 - val_accuracy: 0.9437
# Epoch 12/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.2441 - accuracy: 0.9375 - val_loss: 0.2068 - val_accuracy: 0.9577
# Epoch 13/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.2234 - accuracy: 0.9340 - val_loss: 0.2487 - val_accuracy: 0.9577
# Epoch 14/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.1858 - accuracy: 0.9688 - val_loss: 0.1862 - val_accuracy: 0.9577
# Epoch 15/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.1895 - accuracy: 0.9549 - val_loss: 0.1964 - val_accuracy: 0.9718
# Epoch 16/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1601 - accuracy: 0.9722 - val_loss: 0.2279 - val_accuracy: 0.9718
# Epoch 17/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.1740 - accuracy: 0.9688 - val_loss: 0.1686 - val_accuracy: 1.0000
# Epoch 18/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.1875 - accuracy: 0.9514 - val_loss: 0.2312 - val_accuracy: 0.9296
# Epoch 19/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1617 - accuracy: 0.9618 - val_loss: 0.1809 - val_accuracy: 0.9718
# Epoch 20/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1560 - accuracy: 0.9722 - val_loss: 0.2256 - val_accuracy: 0.9296
# Epoch 21/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1334 - accuracy: 0.9792 - val_loss: 0.2183 - val_accuracy: 0.9437
# Epoch 22/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.1270 - accuracy: 0.9688 - val_loss: 0.2831 - val_accuracy: 0.9014
# Epoch 23/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1142 - accuracy: 0.9861 - val_loss: 0.1558 - val_accuracy: 0.9859
# Epoch 24/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.1080 - accuracy: 0.9861 - val_loss: 0.1765 - val_accuracy: 0.9437
# Epoch 25/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1239 - accuracy: 0.9757 - val_loss: 0.1501 - val_accuracy: 0.9859
# Epoch 26/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1289 - accuracy: 0.9653 - val_loss: 0.1787 - val_accuracy: 0.9718
# Epoch 27/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.1016 - accuracy: 0.9896 - val_loss: 0.1737 - val_accuracy: 0.9437
# Epoch 28/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0973 - accuracy: 0.9965 - val_loss: 0.1721 - val_accuracy: 0.9718
# Epoch 29/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1024 - accuracy: 0.9722 - val_loss: 0.1460 - val_accuracy: 0.9577
# Epoch 30/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.0983 - accuracy: 0.9826 - val_loss: 0.1647 - val_accuracy: 0.9718
# Epoch 31/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.1256 - accuracy: 0.9722 - val_loss: 0.1283 - val_accuracy: 0.9718
# Epoch 32/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.0790 - accuracy: 0.9861 - val_loss: 0.2201 - val_accuracy: 0.9155
# Epoch 33/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.0975 - accuracy: 0.9861 - val_loss: 0.1594 - val_accuracy: 0.9437
# Epoch 34/50
# 9/9 [==============================] - 18s 2s/step - loss: 0.0835 - accuracy: 0.9861 - val_loss: 0.1808 - val_accuracy: 0.9577
# Epoch 35/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.0813 - accuracy: 0.9931 - val_loss: 0.1526 - val_accuracy: 0.9577
# Epoch 36/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0757 - accuracy: 0.9896 - val_loss: 0.2179 - val_accuracy: 0.9296
# Epoch 37/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0809 - accuracy: 0.9792 - val_loss: 0.1869 - val_accuracy: 0.9437
# Epoch 38/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.0808 - accuracy: 0.9826 - val_loss: 0.1546 - val_accuracy: 0.9437
# Epoch 39/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0816 - accuracy: 0.9861 - val_loss: 0.1609 - val_accuracy: 0.9577
# Epoch 40/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0775 - accuracy: 0.9826 - val_loss: 0.1436 - val_accuracy: 0.9437
# Epoch 41/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0876 - accuracy: 0.9792 - val_loss: 0.1302 - val_accuracy: 0.9718
# Epoch 42/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0683 - accuracy: 0.9861 - val_loss: 0.1784 - val_accuracy: 0.9437
# Epoch 43/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.0731 - accuracy: 0.9826 - val_loss: 0.1579 - val_accuracy: 0.9437
# Epoch 44/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.0593 - accuracy: 0.9965 - val_loss: 0.1030 - val_accuracy: 0.9859
# Epoch 45/50
# 9/9 [==============================] - 16s 2s/step - loss: 0.0651 - accuracy: 0.9896 - val_loss: 0.1754 - val_accuracy: 0.9437
# Epoch 46/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.0666 - accuracy: 0.9896 - val_loss: 0.1431 - val_accuracy: 0.9718
# Epoch 47/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.0744 - accuracy: 0.9792 - val_loss: 0.1399 - val_accuracy: 0.9437
# Epoch 48/50
# 9/9 [==============================] - 17s 2s/step - loss: 0.0598 - accuracy: 0.9931 - val_loss: 0.1552 - val_accuracy: 0.9577
# Epoch 49/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.0556 - accuracy: 0.9965 - val_loss: 0.1773 - val_accuracy: 0.9437
# Epoch 50/50
# 9/9 [==============================] - 15s 2s/step - loss: 0.0579 - accuracy: 0.9896 - val_loss: 0.0963 - val_accuracy: 0.9859

# %%
#Graficas de precisión
acc = historial.history['accuracy']
val_acc = historial.history['val_accuracy']

loss = historial.history['loss']
val_loss = historial.history['val_loss']

rango_epocas = range(50)

plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.plot(rango_epocas, acc, label='Precisión Entrenamiento')
plt.plot(rango_epocas, val_acc, label='Precisión Pruebas')
plt.legend(loc='lower right')
plt.title('Precisión de entrenamiento y pruebas')

plt.subplot(1,2,2)
plt.plot(rango_epocas, loss, label='Pérdida de entrenamiento')
plt.plot(rango_epocas, val_loss, label='Pérdida de pruebas')
plt.legend(loc='upper right')
plt.title('Pérdida de entrenamiento y pruebas')
plt.show()

# %%
#Categorizar una imagen de internet
from PIL import Image
import requests
from io import BytesIO
import cv2

def categorizar(url):
  respuesta = requests.get(url)
  img = Image.open(BytesIO(respuesta.content))
  img = np.array(img).astype(float)/255

  img = cv2.resize(img, (224,224))
  prediccion = modelo.predict(img.reshape(-1, 224, 224, 3))
  return np.argmax(prediccion[0], axis=-1)

# %%
#apples=0, bananas=1, cherrys=2, chickoo=3, grapes=4, kiwi=5, mango=6, orange=7, strawberry=8
url = 'https://images.seattletimes.com/wp-content/uploads/2018/01/bafe0de4-f002-11e7-ae5a-0e7cb6fd7c60.jpg?d=568x426' #debe ser 5
prediccion = categorizar (url)
print(prediccion)
# Out:
# 1/1 [==============================] - 0s 56ms/step
# 5
